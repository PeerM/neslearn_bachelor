# %%
import pandas

# %%
# %matplotlib notebook

# %%
df = pandas.read_csv("/home/peer/studium/bachelor/checkpoints/nes_a3c_2/scores_proper.txt",delimiter="\t")

# %%
df[-1:]
# Out:
#         steps       elapsed     mean   median        stdev
# 159  16000000  36192.420799  16220.0  16325.0  4288.257222

# %%
36192/360
# Out:
# 100.53333333333333

# %%
df.plot(y=["mean","median"])
# Out:
# <img src="data:image/png;base64,...">

# %%
df.plot(y="mean",yerr="stdev")
# Out:
# <img src="data:image/png;base64,...">
