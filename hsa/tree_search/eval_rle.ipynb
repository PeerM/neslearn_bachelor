# %%
from rle_python_interface.rle_python_interface import RLEInterface, rle_lib
import matplotlib.pyplot as plt
import numpy as np
from functools import reduce

# %%
# %matplotlib inline

# %%
rle = RLEInterface()

# %%
rle.setBool(b'display_screen', True)
rle.loadROM("/home/peer/heap/Super_Mario_All_Stars.sfc","snes")

# %%
for i in range(120):
    rle.act(0)

# %%
plt.imshow(rle.getScreenRGB())

# %%
plt.imshow(rle.getScreenRGB(np.empty((256,224,4),dtype=np.uint8)))

# %%
screen_data_shape = (256,224,3)
screen_data_size = reduce(lambda x,y:x*y,screen_data_shape)

# %%
screen_data_tmp = np.empty(screen_data_size,dtype=np.uint8)
rle_lib.getScreenRGB(rle.obj,screen_data_tmp.ctypes)
screen_data_tmp
plt.imshow(screen_data_tmp.reshape(screen_data_shape))

# %%
plt.imshow(screen_data_tmp.reshape(screen_data_shape))

# %%
rle_lib.getScreenHeight(rle.obj)
# Out:
# 224

# %%
rle_lib.getScreenWidth(rle.obj)
# Out:
# 256

# %%
rle_lib.RLE_new
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f3d9b9f4c275> in <module>()
# ----> 1 rle_lib.getScreen(rle.obj)
#
# /usr/lib/python3.5/ctypes/__init__.py in __getattr__(self, name)
#     358         if name.startswith('__') and name.endswith('__'):
#     359             raise AttributeError(name)
# --> 360         func = self.__getitem__(name)
#     361         setattr(self, name, func)
#     362         return func
#
# /usr/lib/python3.5/ctypes/__init__.py in __getitem__(self, name_or_ordinal)
#     363
#     364     def __getitem__(self, name_or_ordinal):
# --> 365         func = self._FuncPtr((name_or_ordinal, self))
#     366         if not isinstance(name_or_ordinal, int):
#     367             func.__name__ = name_or_ordinal
#
# AttributeError: /usr/local/lib/python3.5/dist-packages/rle_python_interface/librle_c.so: undefined symbol: getScreen
